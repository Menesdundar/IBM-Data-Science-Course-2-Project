# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mahmud Enes Dündar__

# %% [markdown]
# Yo, what's up everybody?

# %% [markdown]
# _I am interested in Data Science because data scientists earn a lot of money and I would like to be one of them_

# %% [markdown]
# ###  "Quick Maths: 2+2 is 4 minus 1 that's 3"

# %%
def function(x):
    return x

function(2)

print ("2+2 = 4")
print ("4-1 = 3")
# Out:
# 2+2 = 4
# 4-1 = 3

# %% [markdown]
# 1)  Man's not hot with lyrics https://www.youtube.com/watch?v=pa_wRevK6i4&ab_channel=LIQUIDSILVA
# ***
# 2) Short version for lazy people https://www.youtube.com/watch?v=X09oxyIeGuY&ab_channel=musicuploader1000
# ***
# 3) No need for the third one
# ***
